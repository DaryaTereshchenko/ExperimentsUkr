# %%
import pandas as pd 
from statsmodels.stats import inter_rater as irr
import numpy as np

# %%
corpus = pd.read_csv(r"C:\Users\darias\Desktop\UKR\data\Kappa.csv", encoding="utf-8")
c = corpus.iloc[1: , :]
c
# Out:
#                                                Column1  Column2  Column3  \
# 1    ChatGPT не стане популярним в Україні, бо в на...        1        0
# 2    ‼️ Абсолютна влада розбещує. Якщо Рєзніков пог...        1        1
# 3    "Мочити, їх просто треба мочити і не боятися ц...        1        1
# 4    "Невинний" і "росіянин" - це антоніми .\n \n #...        1        0
# 5    "Хутін - пуйло" лунає над стадіоном 🤣🤣🤣\n \n #...        1        1
# ..                                                 ...      ...      ...
# 299  Маю на разі лише одну мрію, щоб вся русня в од...        1        0
# 300  Пообідали під сирену. Повечеряли під сирену. Д...        1        1
# 301  Їхати звідси ми будемо лише тоді, коли роз’єбе...        1        0
# 302  Сподіваюсь настане день і росія припинить своє...        1        1
# 303  Господи! Чому !!!!\n #Ukraine #мова солов’їна ...        1        1
#
#      Column4  Column5  Column6  Column7  Column8  Column9  Column10  Column11  \
# ...

# %%
corpus['sum_1'] = corpus[['Column2','Column3','Column4', 'Column5', 'Column6', 'Column7', 'Column8', 'Column9', 'Column10', 'Column11', 'Column12',
                  'Column13', 'Column14', 'Column15']].sum(axis=1)
corpus['sum_0'] = (corpus[['Column2','Column3','Column4', 'Column5', 'Column6', 'Column7', 'Column8', 'Column9', 'Column10', 'Column11', 'Column12',
                  'Column13', 'Column14', 'Column15']]==0).sum(axis=1)

# %%
data = corpus.iloc[1: , :]
data = data.loc[:, ['sum_1', 'sum_0']].to_numpy()
data
# Out:
# array([[ 9,  5],
#        [ 5,  9],
#        [ 7,  7],
#        [ 3, 11],
#        [ 7,  7],
#        [12,  2],
#        [11,  3],
#        [13,  1],
#        [ 3, 11],
#        [11,  3],
#        [10,  4],
#        [ 8,  6],
#        [ 8,  6],
#        [ 9,  5],
#        [ 8,  6],
#        [ 0, 14],
#        [ 2, 12],
#        [ 0, 14],
#        [ 0, 14],
#        [ 2, 12],
#        [ 3, 11],
#        [ 0, 14],
#        [ 0, 14],
#        [ 2, 12],
#        [ 1, 13],
#        [ 0, 14],
#        [ 0, 14],
#        [ 1, 13],
#        [ 1, 13],
#        [ 1, 13],
#        [ 5,  9],
#        [ 3, 11],
#        [ 7,  7],
#        [ 0, 14],
#        [ 0, 14],
#        [ 0, 14],
#        [ 9,  5],
#        [ 0, 14],
#        [ 2, 12],
#        [ 0, 14],
#        [ 1, 13],
#        [ 0, 14],
#        [ 0, 14],
#        [ 1, 13],
#        [ 0, 14],
#        [ 0, 14],
#        [ 0, 14],
#        [ 5,  9],
#        [ 8,  6],
#        [ 0, 14],
#        [ 1, 13],
#        [ 0, 14],
# ...

# %%
irr.fleiss_kappa(data, method='fleiss')
# Out:
# 0.2558765056718512
